# %%
import numpy as np
a = np.array([1, 2, 3]) # 1D array
print(a)
print(type(a))
print(a.shape)
print(a.ndim)
# Out:
# [1 2 3]
# <class 'numpy.ndarray'>
# (3,)
# 1

# %%
import numpy as np
b = np.array([[1, 2, 3],
             [4, 5, 6]]) # 2D array
print(b)
print(type(b))
print(b.shape)
print(b.ndim)
# Out:
# [[1 2 3]
#  [4 5 6]]
# <class 'numpy.ndarray'>
# (2, 3)
# 2
